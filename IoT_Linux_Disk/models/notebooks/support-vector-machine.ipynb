# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report
import pickle

# %%
IoT = pd.read_csv('../../data/IoT_Linux_Disk.csv')
IoT = IoT.iloc[0:11000]

IoT = IoT.dropna()

encoder=LabelEncoder()
IoT['type']=encoder.fit_transform(IoT['type'])
IoT['PID']=encoder.fit_transform(IoT['PID'])
IoT['RDDSK']=encoder.fit_transform(IoT['RDDSK'])
IoT['WRDSK']=encoder.fit_transform(IoT['WRDSK'])
IoT['WCANCL']=encoder.fit_transform(IoT['WCANCL'])
IoT['DSK']=encoder.fit_transform(IoT['DSK'])
IoT['CMD']=encoder.fit_transform(IoT['CMD'])

IoT.head()
# Out:
# C:\Users\spars\AppData\Local\Temp\ipykernel_16396\1660571340.py:1: DtypeWarning: Columns (2,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   IoT = pd.read_csv('../../data/IoT_Linux_Disk.csv')
#            ts  PID  RDDSK  WRDSK  WCANCL  DSK  CMD  label  type
# 0  1554218915  171     18     57      17   22   72      0     0
# 1  1554218920   79     72     39       1    4  109      0     0
# 2  1554218925  130     71     54      16    4  122      0     0
# 3  1554218930  132     58     56       0    2  147      0     0
# 4  1554218935  156     61     55       0    2  169      0     0

# %%
x = IoT.drop(['label', 'ts', 'type'], axis=1)
y = IoT['label']

features=len(x.columns)

x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2)

# %%
model8 = SVC()

# %%
filename = '../h5s/support-vector-machine.h5'
pickle.dump(model8, open(filename, 'wb'))

# %%
model8.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred = model8.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
accuracy = model8.score(x_test,y_test)
print('Test accuracy:', accuracy)
print(classification_report(y_test, y_pred))
# Out:
# Test accuracy: 0.9986363636363637
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2197
#            1       0.00      0.00      0.00         3
#
#     accuracy                           1.00      2200
#    macro avg       0.50      0.50      0.50      2200
# weighted avg       1.00      1.00      1.00      2200
# C:\Users\spars\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\spars\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\spars\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
